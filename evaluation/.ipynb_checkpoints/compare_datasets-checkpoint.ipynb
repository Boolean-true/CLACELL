# %% [markdown]
# # Compare datasets

# %%
import anndata as ad

# Annes data
h5ad_file='../blood/10x-rep1-kallisto-cellbender/10x-rep1-kallisto-cellbender'
#h5ad_file='../blood/10x-rep2-kallisto-cellbender/10x-rep2-kallisto-cellbender'
#h5ad_file='../blood/bd-rhap-rep1/bd-rhap-rep1'
#h5ad_file='../blood/bd-rhap-rep2/bd-rhap-rep2'

adata_a = ad.io.read_h5ad(f'{h5ad_file}.h5ad')
umi_df_a = adata_a.to_df(layer="counts")

# Celltypist data
adata_b = ad.io.read_h5ad('../CellTypistDataset/global.h5ad')
adata_b = adata_b[adata_b.obs['Organ'] == 'BLD'].copy()
adata_b.layers["counts"] = adata_b.X.copy()
umi_df_b = adata_b.to_df()

# %%
import pandas as pd

def compare_dataframe_features(df1, df2):
    """
    Vergleicht die Spalten (Features) von zwei Pandas DataFrames.
    Gibt die Anzahl der Gemeinsamkeiten und Unterschiede aus und 
    gibt die entsprechenden Sets zurück.
    """
    # Spaltennamen als Sets extrahieren
    features1 = set(df1.columns)
    features2 = set(df2.columns)
    
    # Gemeinsamkeiten und Unterschiede berechnen
    common_features = features1.intersection(features2)
    unique_to_df1 = features1 - features2
    unique_to_df2 = features2 - features1
    all_differences = features1.symmetric_difference(features2)
    
    # Ergebnisse ausgeben
    print("=== Feature-Vergleich ===")
    print(f"Gemeinsame Features: {len(common_features)}")
    print(f"Unterschiedliche Features (insgesamt): {len(all_differences)}")
    print(f"  ↳ Nur in DF1 vorhanden: {len(unique_to_df1)}")
    print(f"  ↳ Nur in DF2 vorhanden: {len(unique_to_df2)}")
    
    # Die tatsächlichen Namen für die weitere Verarbeitung zurückgeben
    return {
        "common": common_features,
        "unique_df1": unique_to_df1,
        "unique_df2": unique_to_df2,
        "all_differences": all_differences
    }




# Compare Dataframes
ergebnisse = compare_dataframe_features(umi_df_a, umi_df_b)

# Du kannst dir die genauen Namen auch anzeigen lassen:
print("\nDie gemeinsamen Features sind:", ergebnisse["common"])
# Out:
# === Feature-Vergleich ===
# Gemeinsame Features: 895
# Unterschiedliche Features (insgesamt): 35800
#   ↳ Nur in DF1 vorhanden: 94
#   ↳ Nur in DF2 vorhanden: 35706
#
# Die gemeinsamen Features sind: {'TSPYL4', 'MTMR9', 'BCL2L1', 'TSPAN33', 'IGKC', 'TSC22D1', 'PSIP1', 'TSPOAP1-AS1', 'CNST', 'SLF1', 'MARCKS', 'IL3RA', 'BASP1', 'VKORC1L1', 'PTMS', 'CLK2', 'AIF1', 'MTSS1', 'TST', 'SOCS1', 'PLEKHG2', 'TMEM176B', 'IGF2R', 'ODC1', 'ERCC6', 'RPS6KA5', 'ERCC6L2', 'RUNX3', 'NR4A1', 'GET1', 'SDR42E2', 'TMEM91', 'PSAP', 'CASP8', 'DNAJB2', 'HOPX', 'CEMIP2', 'TMEM181', 'CX3CR1', 'CD14', 'RUFY1', 'MAX', 'KIF20B', 'TPST2', 'PLAC8', 'SNTB2', 'PRDM1', 'P2RX1', 'DAAM1', 'RBM38', 'SNX9', 'CD27', 'COQ7', 'CPVL', 'KIFAP3', 'AQP9', 'CBLB', 'IRF9', 'SLAMF7', 'ODF2L', 'DBF4', 'SLC25A45', 'DUSP6', 'HIRIP3', 'CCDC14', 'TRDC', 'IFITM3', 'FBXO22', 'CD3G', 'CD151', 'TTC14', 'INF2', 'MORC2', 'ACRBP', 'SOCS3', 'SYNE1', 'TACC3', 'BTG2', 'HOXB2', 'FBXO3', 'GCC2', 'PARP14', 'RCHY1', 'RGS10', 'C12orf57', 'IL1B', 'SNHG12', 'TNFSF10', 'SNAP23', 'TLK1', 'CYREN', 'RHOB', 'CD1C', 'IGSF6', 'VEGFB', 'CLIC3', 'FAM53B', 'DNAJB6', 'CLU', 'ZNF721', 'SUSD3', 'SLC2A3', 'BCL2', 'CST7', 'CD3D', 'SLC35D2', 'KLHL20', 'SKAP1', 'CDK17', 'TRIB1', 'ZNF503', 'GZMK', 'MRPS31', 'LINC00877', 'CD52', 'STMN3', 'SAMD9', 'TRAC', 'HSH2D', 'EVL', 'GFOD1', 'VAV3', 'RAB13', 'MYADM', 'PRKY', 'MAF', 'ANKRD36C', 'ARHGAP18', 'TUBA1B', 'GIMAP7', 'ALOX5AP', 'IRF7', 'CSTA', 'ASAP1', 'RBM28', 'CITED2', 'C5AR1', 'TRBC1', 'OCIAD2', 'PFKP', 'ETFA', 'KLF10', 'HCAR3', 'APLP2', 'CD79B', 'PLPP5', 'TMEM120B', 'CYB561A3', 'HLA-DQB1', 'PTGER2', 'NKG7', 'MT2A', 'CREB5', 'HIF1A', 'LYL1', 'CD69', 'CCL3L1', 'TNFAIP2', 'USP9Y', 'IRF8', 'IL32', 'TMEM216', 'OTUD1', 'BTN3A1', 'VSTM1', 'CTSS', 'GTPBP2', 'S100A9', 'MZF1-AS1', 'UGCG', 'FCER1A', 'CD2AP', 'C12orf75', 'C1orf56', 'CISH', 'MOB1B', 'SOX4', 'FTX', 'ANPEP', 'RASAL3', 'SH2D1A', 'RSU1', 'DAPP1', 'SH3BP5', 'GBP5', 'MFSD6', 'TBC1D4', 'ZNF91', 'MNDA', 'EPS15L1', 'TCF4', 'PLEKHG3', 'POLG2', 'ZFAND2B', 'PARVB', 'SH2D1B', 'TPM4', 'SHTN1', 'PPM1K', 'PRKCH', 'GK5', 'HMOX2', 'SNRPN', 'SOD2', 'MGAT4B', 'KLF12', 'HBEGF', 'ZNF331', 'CHST12', 'IER2', 'GNLY', 'BIRC3', 'GASK1B', 'SPINT2', 'KCNA3', 'TTC38', 'HERC2', 'CEP78', 'ZBTB38', 'PTPN7', 'USP28', 'NMRK1', 'ZEB2', 'PLD4', 'GPRIN3', 'MVD', 'RPH3A', 'RRAS', 'DNAJB1', 'F5', 'IL2RB', 'FGFBP2', 'CD2', 'ADRB2', 'CYTOR', 'PRKCA', 'ZNF224', 'CNOT6L', 'KLRB1', 'KLF4', 'TMC8', 'EIF4A1', 'JADE2', 'PSTPIP2', 'PIP4K2A', 'TUBB1', 'HMGB2', 'YBX3', 'FKBP11', 'PYCR2', 'JAK1', 'MAP4K5', 'PPM1N', 'CENPT', 'CD226', 'KIAA0319L', 'SPTAN1', 'PPBP', 'CD9', 'CXXC5', 'ITM2A', 'PRR7', 'LTB', 'TC2N', 'TCF7', 'SPTBN1', 'PBXIP1', 'FTH1', 'LINC00861', 'SP4', 'MPRIP', 'ZNF292', 'APOBEC3A', 'PTGIR', 'CYFIP2', 'MGAT4A', 'FAM13A', 'HLA-DRA', 'MAFF', 'ABLIM1', 'RCAN3', 'ANO6', 'THEM4', 'ILF3-DT', 'EPB41', 'TREM1', 'OFD1', 'GIHCG', 'TRAF5', 'CALM3', 'SLFN12L', 'GMEB1', 'MFSD8', 'NAMPT', 'CCDC28B', 'CCND3', 'IFI44', 'AMMECR1', 'IFIT2', 'XAF1', 'TSEN54', 'LDLRAP1', 'PRH1', 'SIT1', 'BORCS5', 'PPP1R35', 'BEX2', 'ID2', 'MATK', 'LGALS2', 'SLC4A2', 'GOLT1B', 'METTL8', 'VPS13A', 'MAGED2', 'KAT6A', 'CDKN2D', 'KLHDC4', 'POMC', 'PURA', 'TUT4', 'MAL', 'PDE7A', 'PADI4', 'MDM1', 'CDK6', 'PYGL', 'GAPT', 'RFLNB', 'PTGS1', 'FCER1G', 'ZAP70', 'AIG1', 'TSHZ1', 'NFKBIZ', 'LUCAT1', 'PROK2', 'HEXIM1', 'GCLM', 'GPR141', 'TRIM52', 'VEGFA', 'YWHAH', 'CCDC18-AS1', 'NIBAN1', 'KDM5B', 'TXK', 'LYAR', 'NPRL2', 'ACAP1', 'TECPR2', 'TARBP1', 'SLC39A3', 'MLH3', 'CXCL8', 'ZMIZ2', 'NCOA4', 'TTN-AS1', 'PLEK', 'SNN', 'EMC3', 'RGCC', 'POU2F2', 'PYHIN1', 'ROCK2', 'TCEAL3', 'UBL4A', 'MIR29B2CHG', 'ABHD14A', 'SFXN1', 'PMAIP1', 'SYNE2', 'ZC3H6', 'IFIT3', 'SNHG14', 'AHI1', 'BEX3', 'ILK', 'GABPB1-AS1', 'MCTP2', 'EIF2AK1', 'ATG4D', 'DNAJC9', 'CKB', 'ARPC5L', 'PLBD1', 'NFIA', 'TMEM107', 'CDC14A', 'TNFRSF1B', 'CD247', 'LINC00685', 'RALGPS2', 'PRF1', 'GTF3C1', 'RGL4', 'CRYL1', 'HSPA5', 'RETN', 'CTSC', 'PTGS2', 'RHOH', 'UBE2H', 'CAPN1', 'TUBA1A', 'GAS2L1', 'ZFP14', 'SEPTIN6', 'AKIRIN2', 'RBBP6', 'IL7R', 'C2CD3', 'ABCC3', 'TRG-AS1', 'FAM43A', 'RASSF1', 'SELENOM', 'CDKN1C', 'ERN1', 'C3AR1', 'RGS1', 'IFI44L', 'KLRF1', 'GRAP2', 'ADM', 'IL2RG', 'PPM1A', 'ULK1', 'ATP2A3', 'HLA-DRB1' ...

# %%
import json
import pandas as pd

def check_marker_genes_from_json(df, json_path):
    """
    Lädt Marker-Gene aus einer JSON-Datei und prüft, welche davon
    in den Spalten (Features) des DataFrames vorhanden sind.
    
    Parameters:
    df (pd.DataFrame): Der zu prüfende DataFrame.
    json_path (str): Pfad zur JSON-Datei mit den Marker-Genen.
    
    Returns:
    dict: Ein Wörterbuch mit detaillierten Ergebnissen pro Kategorie/Zelltyp.
    """
    # 1. JSON-Datei mit den Marker-Genen laden
    try:
        with open(json_path, 'r', encoding='utf-8') as file:
            marker_dict = json.load(file)
    except FileNotFoundError:
        print(f"Fehler: Die Datei '{json_path}' wurde nicht gefunden.")
        return None
    except json.JSONDecodeError:
        print(f"Fehler: Die Datei '{json_path}' ist kein gültiges JSON.")
        return None

    # Spaltennamen des DataFrames als Set für ultraschnelle Abgleiche
    df_features = set(df.columns)
    
    ergebnisse = {}
    
    print("=== Marker-Gen Analyse ===")
    
    # 2. Iteration über die Kategorien (z.B. Zelltypen) im JSON
    for kategorie, gene_liste in marker_dict.items():
        # + und - am Ende der Gene entfernen
        gene_set: set[str] = set()
        for g in gene_liste:
            if g.endswith("+") or g.endswith("-"):
                gene_set.add(g[:-1])
            else:
                gene_set.add(g)
        
        # Schnittmenge: Welche Gene sind im DataFrame?
        gefundene_gene = gene_set.intersection(df_features)
        # Differenz: Welche Gene fehlen im DataFrame?
        fehlende_gene = gene_set - df_features
        
        # Prozentualer Anteil der gefundenen Gene berechnen
        gesamt_anzahl = len(gene_set)
        abdeckungsgrad = (len(gefundene_gene) / gesamt_anzahl * 100) if gesamt_anzahl > 0 else 0
        
        # Ergebnisse für diese Kategorie speichern
        ergebnisse[kategorie] = {
            "gefunden": gefundene_gene,
            "fehlend": fehlende_gene,
            "abdeckung_prozent": round(abdeckungsgrad, 2)
        }
        
        # Übersichtliche Ausgabe in der Konsole
        print(f"\nKategorie/Zelltyp: {kategorie}")
        print(f"  -> Abdeckung: {len(gefundene_gene)}/{gesamt_anzahl} ({abdeckungsgrad:.1f}%)")
        print(f"  -> Gefunden: {list(gefundene_gene) if gefundene_gene else 'Keine'}")
        if fehlende_gene:
            print(f"  -> Fehlend: {list(fehlende_gene)}")
            
    return ergebnisse


analyse_resultat = check_marker_genes_from_json(umi_df_a, '../scumi-dev/R/marker_gene/human_pbmc_marker.json')
# Out:
# === Marker-Gen Analyse ===
#
# Kategorie/Zelltyp: CD4+ T cell
#   -> Abdeckung: 10/13 (76.9%)
#   -> Gefunden: ['CD27', 'CD3G', 'GNLY', 'TRAC', 'CD3E', 'TCF7', 'IL7R', 'CST7', 'CD3D', 'NKG7']
#   -> Fehlend: ['CD8A', 'CD4', 'CD8B']
#
# Kategorie/Zelltyp: Cytotoxic T cell
#   -> Abdeckung: 8/11 (72.7%)
#   -> Gefunden: ['CD3G', 'CCL5', 'TRAC', 'CD3E', 'CD3D', 'NKG7', 'FCER1G', 'GZMK']
#   -> Fehlend: ['CD8A', 'CD4', 'CD8B']
#
# Kategorie/Zelltyp: B cell
#   -> Abdeckung: 1/7 (14.3%)
#   -> Gefunden: ['CD79B']
#   -> Fehlend: ['MZB1', 'IGHD', 'IGHM', 'MS4A1', 'CD19', 'CD79A']
#
# Kategorie/Zelltyp: Natural killer cell
#   -> Abdeckung: 12/19 (63.2%)
#   -> Gefunden: ['KLRD1', 'CD3G', 'KLRF1', 'FCGR3A', 'CD14', 'ITGAM', 'TRAC', 'CD3E', 'CD3D', 'NKG7', 'KLRB1', 'FCER1G']
#   -> Fehlend: ['NCAM1', 'KLRC4', 'KLRC3', 'KLRC2', 'ITGAL', 'FCGR3B', 'KLRC1']
#
# Kategorie/Zelltyp: CD14+ monocyte
#   -> Abdeckung: 17/22 (77.3%)
#   -> Gefunden: ['KLRD1', 'CX3CR1', 'CD3G', 'CD14', 'FCGR3A', 'ITGAM', 'S100A9', 'TRAC', 'CD3E', 'S100A8', 'CSF3R', 'FCN1', 'S100A12', 'CD3D', 'NKG7', 'KLRB1', 'VCAN']
#   -> Fehlend: ['TYROBP', 'CSF1R', 'ITGAL', 'FCGR3B', 'LYZ']
#
# Kategorie/Zelltyp: CD16+ monocyte
#   -> Abdeckung: 18/21 (85.7%)
#   -> Gefunden: ['KLRD1', 'CX3CR1', 'CD3G', 'CD14', 'FCGR3A', 'ITGAM', 'S100A9', 'TRAC', 'CD3E', 'S100A8', 'CSF3R', 'FCN1', 'S100A12', 'CD3D', 'CDKN1C', 'MS4A7', 'KLRB1', 'NKG7']
#   -> Fehlend: ['ITGAL', 'CSF1R', 'FCGR3B']
#
# Kategorie/Zelltyp: Dendritic cell
#   -> Abdeckung: 11/18 (61.1%)
#   -> Gefunden: ['HLA-DPA1', 'CD3G', 'CD14', 'HLA-DQA1', 'HLA-DPB1', 'CD3E', 'CD79B', 'FCER1A', 'CD3D', 'CD1C', 'CLEC10A']
#   -> Fehlend: ['NCAM1', 'CD19', 'FCGR2B', 'MS4A1', 'ITGAX', 'CD79A', 'CD1E']
#
# Kategorie/Zelltyp: Plasmacytoid dendritic cell
#   -> Abdeckung: 9/17 (52.9%)
#   -> Gefunden: ['TCF4', 'CD3G', 'CD14', 'IRF7', 'CD79B', 'CD3E', 'GZMB', 'CD3D', 'IL3RA']
#   -> Fehlend: ['NCAM1', 'CD19', 'MS4A1', 'CLEC4C', 'ITGAX', 'CD79A', 'JCHAIN', 'LILRA4']
#
# Kategorie/Zelltyp: Plasma cell
#   -> Abdeckung: 6/15 (40.0%)
#   -> Gefunden: ['CD27', 'CD3G', 'CD3E', 'XBP1', 'SLAMF7', 'CD3D']
#   -> Fehlend: ['IGHG1', 'IGHG3', 'CD38', 'CD19', 'MS4A1', 'IGHA2', 'IGHG4', 'IGHA1', 'IGHG2']
#
# Kategorie/Zelltyp: Megakaryocyte
#   -> Abdeckung: 6/10 (60.0%)
#   -> Gefunden: ['RGS18', 'TUBB1', 'NRGN', 'SPARC', 'GNG11', 'PPBP']
#   -> Fehlend: ['PF4', 'GP5', 'ITGA2B', 'MYL9']
